# %% [markdown]
# <a href="https://colab.research.google.com/github/danielruizm16/ComputationalMethods_2026_I/blob/main/Interpolación/Tarea_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Abrir en Colab"/></a>

# %% [markdown]
# # Tarea 04: Interpolación.
#
# ---
# ### Profesor: Daniel Ruiz Mejía
# ### Nombre: ______
# *Métodos Computacionales 2026-I*
#
# ---

# %% [markdown]
# # 1.
#
# Los siguientes datos definen la concentración de oxígeno disuelto al nivel del mar para agua dulce como función de la temperatura:
# ```
# T = np.array([0, 8, 16, 24, 32, 40]) # Temperatura en °C
# o = np.array([14.621, 11.843, 9.870, 8.418, 7.305, 6.413]) # Concentración en mg/L
# ```
# Estimar $o(27)$ usando:
# - Interpolación lineal
# - Polinomio de interpolación de Newton
# - Splines cúbicos
#
# Graficar las funciones obtenidas con el programa junto con los datos proporcionados.

# %%
# Aquí va su código

# %% [markdown]
# # 2.
# Los valores de la aceleración gravitacional $g$ dependen de la altitud $y$ como se muestra en la tabla. Usar el método de diferencias divididas de Newton para estimar el valor de la aceleración gravitacional a altitudes de 5.000 m, 42.000 m y 90.000 m. Graficar el comportamiento de la función de interpolación obtenida junto con los datos dados.
#
# ```
# y = [0, 20000, 40000, 60000, 80000] # en metros
# g = [9.8100, 9.7487, 9.6879, 9.6278, 9.5682] # en m/s²
# ```
#
# **Nota:** Para el cálculo de la tabla de diferencias divididas, no utilice una función recursiva. En su lugar, diseñe un algoritmo basado en ciclos iterativos (loops) para construir la matriz de coeficientes de manera eficiente.

# %%
# Aquí va su código

# %% [markdown]
# # 3.
# Se mide un automóvil que viaja a lo largo de una carretera recta en varios puntos. Los datos de observación se presentan en la siguiente tabla, donde el tiempo está en segundos, la distancia en metros y la velocidad en metros por segundo.
#
# ```
# time = np.array([0, 3, 5, 8, 13]) # segundos
# distance = np.array([0, 225, 383, 623, 993]) # meters
# speed = np.array([75, 77, 80, 74, 72]) # metros/segundo
# ```
#
# - Usar un polinomio de Hermite y splines cúbicos para predecir la posición del automóvil y su velocidad cuando $t=10$ s.
# - ¿Cuál es la velocidad máxima predicha para el automóvil en cada caso?
#
# Graficar las funciones obtenidas con el programa junto con los datos proporcionados.

# %%
# Aquí va su código

# %% [markdown]
# # 4.
# El conjunto de datos de la siguiente tabla representa el desplazamiento $u$ de un resorte debido a una fuerza aplicada $F$. Usar un programa que implemente el método de diferencias divididas de Newton y el método de interpolación de Lagrange para estimar la fuerza requerida para desplazar el resorte en $0.3  \text{ m}$ y $0.4  \text{ m}$. Luego, graficar la función obtenida con el programa junto con los datos proporcionados.
#
# ```
# u = np.array([0.107, 0.172, 0.238, 0.351, 0.388, 0.417, 0.432, 0.441]) # desplazamiento (m)
# F = np.array([100, 200, 300, 400, 500, 600, 700, 800]) # fuerza (kN)
# ```

# %%
# Aquí va su código

# %% [markdown]
# # 5.
# El índice de refracción del vidrio de borosilicato a diferentes longitudes de onda se presenta en la siguiente tabla. Estimar la longitud de onda para la cual el índice de refracción es 1.520.
#
# ```
# lambda_angstrom = np.array([6563, 6439, 5890, 5338, 5086, 4861, 4340, 3988]) # en Å
# refractive_index = np.array([1.50883, 1.50917, 1.51124, 1.51386, 1.51534, 1.51690, 1.52136, 1.52546])
# ```
#
# Graficar la función obtenida con el programa junto con los datos proporcionados.

# %%
# Aquí va su código
