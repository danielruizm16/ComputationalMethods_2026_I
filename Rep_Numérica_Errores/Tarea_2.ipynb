# %% [markdown]
# <a href="https://colab.research.google.com/github/danielruizm16/ComputationalMethods_2026_I/blob/main/Rep_Numérica_Errores/Tarea_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Tarea 02: Representación Numérica, Errores y Estabilidad.
#
# ---
# ### Profesor: Daniel Ruiz Mejía
# ### Nombre: ______
# *Métodos Computacionales 2026-I*
#
# ---

# %% [markdown]
# # 1.
#
# Cree una función llamada `myint` que a partir de un número binario con base de 16 bits encuentre el número entero correspondiente. Compare su resultado con `int(0b1000011100001)`

# %%
# Aquí va su código

# %% [markdown]
# # 2. Aproximación de $\pi$
# La serie de Maclaurin para la función arcotangente converge para $-1 < x \leq 1$ y está dada por:
#
# $$
# \arctan x = \lim_{n \to \infty} P_n(x) = \lim_{n \to \infty} \sum_{i=1}^n (-1)^{i+1} \frac{x^{2i-1}}{2i-1}
# $$
#
# - **Aproximación básica**
#     - Usando el hecho de que $\tan(\pi/4) = 1$, implemente una función en Python que calcule $4P_n(1)$ y determine el número mínimo de términos $n$ necesario para que $|4P_n(1) - \pi| < 10^{-3}$. Compare su resultado con el valor de $\pi$ de la librería numpy.
#     - Requiriendo que el valor de $\pi$ esté dentro de un error de $10^{-4}$. ¿Cuántos términos de la serie serían necesarios sumar para lograr esta precisión? Implemente una solución en Python para encontrar este valor.
#
# - **Mejora de la convergencia**
#     El método anterior se puede mejorar significativamente usando la identidad:
#     $$
#     \frac{\pi}{4} = \arctan\left(\frac{1}{2}\right) + \arctan\left(\frac{1}{3}\right)
#     $$
#     - Implemente una función en Python que evalúe la serie para $\arctan(1/2)$ y $\arctan(1/3)$ por separado y luego las sume. Determine el número mínimo de términos necesarios para cada serie (pueden ser diferentes) para aproximar $\pi$ con un error menor a $10^{-3}$ y $10^{-6}$.
#
# - **Método de alta precisión**
#     Para obtener una convergencia aún más rápida, use la identidad:
#     $$
#     \frac{\pi}{4} = 4\arctan\left(\frac{1}{5}\right) - \arctan\left(\frac{1}{239}\right)
#     $$
#     - El número mínimo de términos necesarios en cada serie para aproximar $\pi$ con error menor a $10^{-3}$ y $10^{-6}$.
#     - Compare el rendimiento (número de términos requeridos) con los métodos anteriores.

# %%
# Aquí va su código

# %% [markdown]
# # 3.
# Escriba un programa para calcular los errores absoluto y relativo en la aproximación de Stirling
#
# $$
# n! \approx \sqrt{2\pi n} \, (n/e)^n
# $$
#
# para $n = 1, \ldots, 10$. ¿El error absoluto crece o disminuye a medida que $n$ aumenta? ¿El error relativo crece o disminuye a medida que $n$ aumenta?

# %%
# Aquí va su código

# %% [markdown]
# # 4.
# Considere una ecuación cuadrática $ ax^2 + bx + c = 0 $ que tiene soluciones reales.
#
# - Escriba un programa que reciba como entrada tres números, $a$, $b$ y $c$, e imprima las dos soluciones de la ecuación cuadrática $ ax^2 + bx + c = 0 $ usando la fórmula estándar
#     $$
#     x = \frac{-b \pm \sqrt{b^2 - 4ac}}{2a}.
#     $$
#
#     Use su programa para calcular las soluciones de $0.001x^2 + 1000x + 0.001 = 0$.
#
# - Hay otra forma de escribir las soluciones de una ecuación cuadrática. Multiplicando el numerador y el denominador de la solución anterior por $-b \mp \sqrt{b^2 - 4ac}$, las soluciones también se pueden escribir como
#     $$
#     x = \frac{2c}{-b \mp \sqrt{b^2 - 4ac}}.
#     $$
#
#     Añada más líneas a su programa para imprimir estos valores además de los anteriores y use nuevamente el programa para resolver $ 0.001x^2 + 1000x + 0.001 = 0 $. ¿Qué observa? ¿Cómo lo explica?
#
# - Usando lo que ha aprendido, escriba un nuevo programa que calcule ambas raíces de una ecuación cuadrática con precisión en todos los casos.

# %%
# Aquí va su código
