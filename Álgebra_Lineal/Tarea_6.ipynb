# %% [markdown]
# <a href="https://colab.research.google.com/github/danielruizm16/ComputationalMethods_2026_I/blob/main/Álgebra_Lineal/Tarea_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Abrir en Colab"/></a>

# %% [markdown]
# # Tarea 06: Álgebra lineal.
#
# ---
# ### Profesor: Daniel Ruiz Mejía
# ### Nombre: ______
# *Métodos Computacionales 2026-I*
#
# ---

# %% [markdown]
# # 1.
#
# Sea $A\in\mathbb{R}^{n\times n}$ una matriz no singular y sea $b\in\mathbb{R}^n$.
# Descomponga $A$ como
#
# $$
# A \;=\; D \;+\; L \;+\; U,
# $$
#
# donde:
#
# - $D$ es la matriz diagonal de $A$,
# - $L$ es la parte triangular estrictamente inferior,
# - $U$ es la parte triangular estrictamente superior.
#
# El algoritmo de Gauss-Seidel reorganiza el sistema $Ax=b$ como
#
# $$
# x \;=\; (D+L)^{-1}\bigl(b \;-\; Ux\bigr),
# $$
#
# y genera la sucesión
#
# $$
# x_i^{(k+1)}
# = \frac{1}{a_{ii}}
# \Bigl(b_i - \sum_{j<i} a_{ij}\,x_j^{(k+1)} - \sum_{j>i} a_{ij}\,x_j^{(k)}\Bigr),
# \qquad i=1,\dots,n.
# $$
#
# - Implemente una función `gauss_seidel(A, b, tol=1e-7, max_iter=100)` que:
#    * Realice iteraciones hasta que
#      $\lVert x^{(k+1)}-x^{(k)}\rVert_\infty<\text{tol}$
#      o hasta que se alcance `max_iter`.
#    * Devuelva el vector solución aproximado $x$, el número de iteraciones realizadas y la norma del último residuo.
#
# Luego,
#
#    * Genere una matriz aleatoria de $5\times5$ (por ejemplo, usando `np.random.rand`) y un vector aleatorio $b$.
#    * Resuelva $Ax=b$ usando su función; calcule el error relativo comparado con `numpy.linalg.solve`.
#    * Estime también el error relativo con respecto a la solución obtenida mediante $x=A^{-1}b$ (usando `numpy.linalg.inv`).
#    * Presente las normas de los residuos y los errores relativos.
#
# **Opcional:**
#
# El método SOR es una extensión del método de Gauss-Seidel que usa un factor de relajación $\omega$ para acelerar la convergencia. Descompone la matriz $A$ como:
#
# $$
# A = D + L + U,
# $$
# donde:
# - $D$: matriz diagonal de $A$,
# - $L$: matriz triangular estrictamente inferior,
# - $U$: matriz triangular estrictamente superior.
#
# La fórmula de iteración SOR es:
#
# $$
# x^{(k+1)} = (D + \omega L)^{-1}[\omega b - (\omega U + (\omega - 1)D)x^{(k)}]
# $$
#
# La forma componente a componente es:
# $$
# x_i^{(k+1)} = (1-\omega)x_i^{(k)} + \frac{\omega}{a_{ii}}\left(b_i - \sum_{j=1}^{i-1} a_{ij}x_j^{(k+1)} - \sum_{j=i+1}^{n} a_{ij}x_j^{(k)}\right)
# $$
#
# - Escriba una función explícita que implemente el método SOR con una tolerancia de 1e-7, un máximo de 100 iteraciones y que reciba el parámetro de relajación $\omega$ como entrada. Incluya documentación completa.
# - Para una matriz aleatoria de 5×5, encuentre la solución usando su función con $\omega$ = 1.2 y determine el error con respecto tanto a `numpy.linalg.solve()` como al método de la matriz inversa.
# - Compare el comportamiento de convergencia para diferentes valores de $\omega$ (0.5, 1.0, 1.5) y analice los resultados.

# %%
# Aquí va tu código

# %% [markdown]
# # 2.
# Considere el circuito de la figura. Usando las leyes de Kirchhoff, escriba las ecuaciones para la corriente y el voltaje. Luego, determine la forma matricial y encuentre los valores de la corriente que fluye por cada nodo, es decir, $i_{12}$, $i_{23}$, etc.
#
#
# ![image.png](data:image/png;base64,...)

# %%
# Aquí va tu código

# %% [markdown]
# # 3.
# Se sabe que un sistema físico está gobernado por las ecuaciones,
#
# $$
# \begin{matrix}
# x' &=& 2x&-y&+z, \\
# y' &=&   &3y&-z, \\
# z' &=& 2x&+y&+3z,
# \end{matrix}
# $$
#
# donde $x',y',z'$ son las derivadas. En forma vectorial, esto puede representarse como $\mathbf{r}'=A\mathbf{r}$, cuya solución analítica general es $\mathbf{r} = e^{At} \mathbf{r}(0)$.
#
# - Realice la diagonalización de $A$.
#
# - Use el hecho de que $f(A) =U f(D) U^{-1}$ para encontrar $x(t),y(t),z(t)$ en el intervalo de tiempo $[0,2]$.
#
# - Grafique $x(t),y(t),z(t)$ (use la condición inicial $\mathbf{r}(0)=(1,1,2)$).
#
# - Compare el resultado con la solución analítica,
#
# $$
# 2x  = x(0)(e^{2t}(1+e^{2t}-2t)) + y(0) (-2te^{2t}) + z(0)(e^{2t}(-1+e^{2t})),
# $$
#
# $$
# 2y  = x(0)(-e^{2t}(-1+e^{2t}-2t)) + y(0)(2(t+1)e^{2t}) + z(0)(-e^{2t}(-1+e^{2t})),
# $$
#
# $$
# 2z  = x(0)(e^{2t}(-1+e^{2t}+2t)) + y(0)(2te^{2t}) + z(0)(e^{2t}(1+e^{2t})).
# $$

# %%
# Aquí va tu código

# %% [markdown]
# # 4.
# Sea $A\in\mathbb{R}^{n\times n}$ una matriz diagonalizable con valor propio dominante $\lambda\_{\max}$ (en magnitud) y vector propio asociado $v\_{\max}$.
#
# El método de la potencia genera, a partir de un vector inicial $q^{(0)}\neq 0$, la sucesión
#
# $$
# q^{(k+1)} \;=\; \frac{A\,q^{(k)}}{\lVert A\,q^{(k)}\rVert_2},
# \qquad
# \lambda^{(k+1)} \;=\; (q^{(k+1)})^{\!\top} A\, q^{(k+1)},
# $$
#
# la cual converge a $v\_{\max}/\lVert v\_{\max}\rVert\_2$ y a $\lambda\_{\max}$, respectivamente, bajo las hipótesis estándar.
#
# Implemente `power_method(A, tol=1e-7, max_iter=1000)` que:
#
# - Acepte matrices cuadradas reales.
# - Devuelva $\lambda\_{\max}$, el vector propio normalizado $v\_{\max}$, el número de iteraciones y la última variación relativa de $\lambda$.
# - Detenga la iteración cuando $\bigl|\lambda^{(k+1)}-\lambda^{(k)}\bigr|<\text{tol}\,|\lambda^{(k+1)}|$ o cuando se alcance `max_iter`.
#
# Luego,
# - Genere una matriz simétrica aleatoria de $6\times6$ (por ejemplo, $A = (M+M^\top)/2$ con $M$ aleatoria).
# - Aplique su `power_method` y compare $\lambda\_{\max}$ y $v\_{\max}$ con los resultados de `numpy.linalg.eig`.

# %%
# Aquí va tu código

# %% [markdown]
# # 5.
# Un electrón interactúa con un campo magnético uniforme. Para determinar los niveles de energía permitidos del electrón en presencia del campo magnético, es necesario resolver la ecuación:
#
# $$
# \hat{H}|\Psi\rangle = E|\Psi\rangle
# $$
#
# donde el Hamiltoniano está dado por $H = -\bm{\mu} \cdot \bm{B} = -\gamma \bm{B} \cdot \bm{S}$, con $\gamma$ como la razón giromagnética, $\bm{B}$ el campo magnético y $\bm{S}$ el espín. Se puede demostrar que el Hamiltoniano se expresa como:
#
# $$
# \hat{H} = -\frac{\gamma\hbar}{2}\begin{pmatrix}
# B_z & B_x - iB_y \\
# B_x + iB_y & -B_z
# \end{pmatrix}
# $$
#
# El valor experimental de $\gamma$ para el electrón es 2. El orden de magnitud del campo magnético es de 1 gauss en la dirección $z$.
#
# - Verifique que $H$ es hermítico.
# - Encuentre los niveles de energía permitidos (valores propios).
# - Determine los vectores propios y verifique su normalización.

# %%
# Aquí va tu código
